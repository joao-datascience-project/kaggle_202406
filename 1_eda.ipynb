# %% [markdown]
# # EDA
#
# > Content: Exploratory Data Analysis of the challenge data

# %% [markdown]
# # Packages Imports

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import sys

# %%
# Append folder with data
sys.path.append("/Users/joaocosta/Desktop/data_science_joao_projects/202406_kaggle/data/")

# %%
print(sys.path)
# Out:
# ['/Users/joaocosta/Desktop/data_science_joao_projects/kaggle/202406_academic_success', '/Users/joaocosta/Desktop/data_science_joao_projects/Ironman/notebooks', '/Users/joaocosta/.vscode/extensions/ms-toolsai.jupyter-2022.11.1003412109/pythonFiles', '/Users/joaocosta/.vscode/extensions/ms-toolsai.jupyter-2022.11.1003412109/pythonFiles/lib/python', '/Users/joaocosta/opt/anaconda3/envs/kaggle_202406/lib/python312.zip', '/Users/joaocosta/opt/anaconda3/envs/kaggle_202406/lib/python3.12', '/Users/joaocosta/opt/anaconda3/envs/kaggle_202406/lib/python3.12/lib-dynload', '', '/Users/joaocosta/opt/anaconda3/envs/kaggle_202406/lib/python3.12/site-packages', '/Users/joaocosta/Desktop/data_science_joao_projects/202406_kaggle/data', '/Users/joaocosta/Desktop/data_science_joao_projects/202406_kaggle/data/']

# %% [markdown]
# # Import Data

# %%
train_data = pd.read_csv('/Users/joaocosta/Desktop/data_science_joao_projects/kaggle/202406_academic_success/data/train.csv')

# %% [markdown]
# # General Exploratory

# %%
# Head

train_data.head(5)
# Out:
#    id  Marital status  Application mode  Application order  Course  \
# 0   0               1                 1                  1    9238
# 1   1               1                17                  1    9238
# 2   2               1                17                  2    9254
# 3   3               1                 1                  3    9500
# 4   4               1                 1                  2    9500
#
#    Daytime/evening attendance  Previous qualification  \
# 0                           1                       1
# 1                           1                       1
# 2                           1                       1
# 3                           1                       1
# 4                           1                       1
#
#    Previous qualification (grade)  Nacionality  Mother's qualification  ...  \
# 0                           126.0            1                       1  ...
# 1                           125.0            1                      19  ...
# ...

# %%
# Features info
train_data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 76518 entries, 0 to 76517
# Data columns (total 38 columns):
#  #   Column                                          Non-Null Count  Dtype
# ---  ------                                          --------------  -----
#  0   id                                              76518 non-null  int64
#  1   Marital status                                  76518 non-null  int64
#  2   Application mode                                76518 non-null  int64
#  3   Application order                               76518 non-null  int64
#  4   Course                                          76518 non-null  int64
#  5   Daytime/evening attendance                      76518 non-null  int64
#  6   Previous qualification                          76518 non-null  int64
#  7   Previous qualification (grade)                  76518 non-null  float64
#  8   Nacionality                                     76518 non-null  int64
# ...

# %% [markdown]
# > **CONCLUSIONS**:
# - 38 Columns
# - 76518 Rows
# - Apparently no missing values
# - Only the target is an object type

# %%
# Statistical Describe
# Adding unique counting to the describe table
unique_counts = train_data.nunique()
unique_counts_df = pd.DataFrame(unique_counts, columns=['nunique']).T
pd.concat([train_data.describe(), unique_counts_df]).T
# Out:
#                                                   count          mean  \
# id                                              76518.0  38258.500000
# Marital status                                  76518.0      1.111934
# Application mode                                76518.0     16.054419
# Application order                               76518.0      1.644410
# Course                                          76518.0   9001.286377
# Daytime/evening attendance                      76518.0      0.915314
# Previous qualification                          76518.0      3.658760
# Previous qualification (grade)                  76518.0    132.378766
# Nacionality                                     76518.0      1.226600
# Mother's qualification                          76518.0     19.837633
# Father's qualification                          76518.0     23.425076
# Mother's occupation                             76518.0      8.583196
# ...

# %% [markdown]
# > **CONCLUSIONS**:
# - There are columns coded as integers but in reality are ID-type columns, such as :
#
#     id, Marital Status, Application mode, Course, Previous qualification, Nacionality,
# Mother's qualification, Father's qualification, Mother's occupation, Father's occupation
# - These might require special feature encoding

# %% [markdown]
# # Univariate Evaluation of each Feature

# %%
train_data.columns
# Out:
# Index(['id', 'Marital status', 'Application mode', 'Application order',
#        'Course', 'Daytime/evening attendance', 'Previous qualification',
#        'Previous qualification (grade)', 'Nacionality',
#        'Mother's qualification', 'Father's qualification',
#        'Mother's occupation', 'Father's occupation', 'Admission grade',
#        'Displaced', 'Educational special needs', 'Debtor',
#        'Tuition fees up to date', 'Gender', 'Scholarship holder',
#        'Age at enrollment', 'International',
#        'Curricular units 1st sem (credited)',
#        'Curricular units 1st sem (enrolled)',
#        'Curricular units 1st sem (evaluations)',
#        'Curricular units 1st sem (approved)',
#        'Curricular units 1st sem (grade)',
#        'Curricular units 1st sem (without evaluations)',
#        'Curricular units 2nd sem (credited)',
#        'Curricular units 2nd sem (enrolled)',
#        'Curricular units 2nd sem (evaluations)',
# ...

# %%
train_data['Marital status'].isna().sum()
# Out:
# 0

# %%
train_data['Marital status'].value_counts()
# Out:
# Marital status
# 1    70189
# 2     5296
# 4      866
# 5      116
# 6       35
# 3       16
# Name: count, dtype: int64

# %%
ax = train_data['Marital status'].value_counts().sort_index().plot(kind='bar',rot=0)

# iterate over the bars and annotate each one
for p in ax.containers:
    for q in p:
        ax.annotate(str(round(q.get_height(), 2)),
                    (q.get_x() + q.get_width() / 2., q.get_height()),
                    ha='center', va='center', xytext=(0, 10), textcoords='offset points')
plt.title(f"relative frequencies for each label")
# Out:
# Text(0.5, 1.0, 'relative frequencies for each label')

# %%
ax = train_data['Marital status'].value_counts(normalize=True).sort_index().plot(kind='bar',rot=0)

# iterate over the bars and annotate each one
for p in ax.containers:
    for q in p:
        ax.annotate(str(round(q.get_height(), 4)),
                    (q.get_x() + q.get_width() / 4., q.get_height()),
                    ha='center', va='center', xytext=(0, 10), textcoords='offset points')
plt.title(f"Proportions for each label")
# Out:
# Text(0.5, 1.0, 'Proportions for each label')

# %%
train_data.groupby('Marital status')['Target'].value_counts(normalize=True).unstack().plot(kind='bar', stacked=True, rot=True, title='Target proportion for each label')
# Out:
# <Axes: title={'center': 'Target proportion for each label'}, xlabel='Marital status'>
